# %%
name , age ,place , education ="dilna", 20 , "wayanad" ,"degree"

# %%
name
# Out:
# 'dilna'

# %%
age
# Out:
# 20

# %%
age=25

# %%
age
# Out:
# 25

# %%
education=pg
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_540/1561855052.py in <cell line: 0>()
# ----> 1 education=pg
#
# NameError: name 'pg' is not defined

# %%
education=pg

# %%
education
# Out:
# 'degree'

# %%
education="pg"

# %%
education
# Out:
# 'pg'

# %% [markdown]
#       Variables are containers for storing data values
#
# Rules  for naming variables:
#
#   *  1.Must start with a letter or underscore_
#   *  2.Cannot start with a number
#   *  3.can contain letters,digits,and underscore
#   *  4.case-sensitive(`Name`#`name`)
#   *  5.should not use Python keywords(if, for,class,etc.)

# %%
Variable Assignment in Python

# %%
X =10  #Assign the integar 10 to variable x
name="alice"
_price=99.99
is_active=True
print(X, name,_price, is_active)
# Out:
# 10 alice 99.99 True

# %%
name='Athiq'
name
print(name)
print("name")
print("my name is", name)
print("my name is", name, "and everyone call me",name)
print(type(x))
# Out:
# Athiq
# name
# my name is Athiq
# my name is Athiq and everyone call me Athiq
# <class 'str'>
# <class 'int'>

# %% [markdown]
# # newsection
